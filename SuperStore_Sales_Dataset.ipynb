# %% [markdown]
# Important Laibary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# import Data Set 'Super store sales Data'

# %%
df = pd.read_csv('C:\\Users\\Sopnil\\Downloads\\SuperStore_Sales_Dataset\\SuperStore_Sales_Dataset.csv')
df
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# ...

# %% [markdown]
# View the shape of the Dataframe that contains the number of rows and the number of columns.

# %%
df.shape
# Out:
# (5901, 23)

# %% [markdown]
# View all the columns in the Dataframe.

# %%
df.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode', 'ind1',
#        'ind2'],
#       dtype='object')

# %% [markdown]
# View all the columns null values in the Dataframe.

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %% [markdown]
# View the statistical description of the Dataframe. Description contains the count of features, mean of them, Standard deviation, minimum and maximum values in that particular attribute, 25%, 50%, 75% of the values in the dataset. To view the statistical description of the dataset, use the describe() method.

# %%
df.describe()
# Out:
#        Row ID+O6G3A1:R6        Sales     Quantity       Profit  Returns  ind1  \
# count       5901.000000  5901.000000  5901.000000  5901.000000    287.0   0.0
# mean        5022.422471   265.345589     3.781901    29.700408      1.0   NaN
# std         2877.977184   474.260645     2.212917   259.589138      0.0   NaN
# min            1.000000     0.836000     1.000000 -6599.978000      1.0   NaN
# 25%         2486.000000    71.976000     2.000000     1.795500      1.0   NaN
# 50%         5091.000000   128.648000     3.000000     8.502500      1.0   NaN
# 75%         7456.000000   265.170000     5.000000    28.615000      1.0   NaN
# max         9994.000000  9099.930000    14.000000  8399.976000      1.0   NaN
#
#        ind2
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %% [markdown]
# View the information like Range index, datatypes, number of non-null entries for each column by using the info() method.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
# ...

# %% [markdown]
# The dataset has an order date column i use this column to create new columns like order month, order year, and order day.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date']) 

df['Order Month'] = df['Order Date'].dt.month 
df['Order Year'] = df['Order Date'].dt.year
df['Order Day of Week'] = df['Order Date'].dt.dayofweek
# Out:
# C:\Users\Sopnil\AppData\Local\Temp\ipykernel_10440\2945290660.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
# C:\Users\Sopnil\AppData\Local\Temp\ipykernel_10440\2945290660.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.head()
# Out:
#    Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304 2019-01-01 2019-07-01  Standard Class
# 1              4919  CA-2019-160304 2019-02-01 2019-07-01  Standard Class
# 2              4920  CA-2019-160304 2019-02-01 2019-07-01  Standard Class
# 3              3074  CA-2019-125206 2019-03-01 2019-05-01     First Class
# 4              8604  US-2019-116365 2019-03-01 2019-08-01  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
# ...

# %%
sales_by_month = df.groupby('Order Month')['Sales'].sum().reset_index()
sales_by_month
# Out:
#     Order Month        Sales
# 0             1  118934.4350
# 1             2  100157.8994
# 2             3  138636.1288
# 3             4   96020.2796
# 4             5  122174.7682
# 5             6  101640.2685
# 6             7  113457.4825
# 7             8  135676.2924
# 8             9  143865.7503
# 9            10  131574.3122
# 10           11  177411.8250
# 11           12  186254.8813

# %%
sales_by_month.plot.line()
plt.title('Monthly Sales Analysis')
fig.show()
# Out:
# C:\Users\Sopnil\AppData\Local\Temp\ipykernel_10440\390218150.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# View sales column groupby and  Category data

# %%
sales_by_category = df.groupby('Category')['Sales'].sum().reset_index()
sales_by_category
# Out:
#           Category        Sales
# 0        Furniture  451508.6452
# 1  Office Supplies  643707.6870
# 2       Technology  470587.9910

# %% [markdown]
# Visualizations Category by Sales

# %%
fig=plt.figure(figsize=(12,7))
plt.title('Category by Sales')
sns.barplot(data=sales_by_category, x='Category',y ='Sales')
#plt.show()
plt.savefig('C:\\Users\\Sopnil\\Downloads\\barchat.png')

# %%
fig = plt.figure(figsize =(10, 7))
plt.title('Category by Sales with %')
plt.pie(sales_by_category['Sales'], labels =sales_by_category['Category'],autopct='%.0f%%')
plt.show()

# %% [markdown]
# View sales column groupby and Sub-Category data

# %%
df_sub_category = df.groupby('Sub-Category')['Sales'].sum().reset_index()
df_sub_category
# Out:
#    Sub-Category        Sales
# 0   Accessories  122301.0860
# 1    Appliances   80305.2470
# 2           Art   50762.9760
# 3       Binders  174978.3900
# 4     Bookcases   57577.6862
# 5        Chairs  181945.9980
# 6       Copiers   59735.7980
# 7     Envelopes   16542.4640
# 8     Fasteners   15205.2380
# 9   Furnishings   92691.2180
# 10       Labels   19397.4560
# 11     Machines   91987.5610
# 12        Paper   99453.6120
# 13       Phones  196563.5460
# 14      Storage  150341.3180
# 15     Supplies   36720.9860
# 16       Tables  119293.7430

# %% [markdown]
# Visualizations Sub Category by Sales

# %%
plt.rcParams['figure.figsize']=(15,6)
plt.bar(df['Sub-Category'],df['Sales']);
plt.rcParams.update({'font.size':10});
plt.title('Sales by Sub-Category');
plt.xlabel('Sub_Category');
plt.ylabel('Sales');

# %%
plt.title('Region count')
sns.countplot(x='Region',data=df, color='green', saturation=1)

plt.show()

# %%
profit_by_month = df.groupby('Order Month')['Profit'].sum().reset_index()
profit_by_month
# Out:
#     Order Month      Profit
# 0             1  19408.8509
# 1             2  18927.6872
# 2             3  20078.2101
# 3             4   1533.2429
# 4             5  17542.7608
# 5             6  11876.7109
# 6             7  11120.3953
# 7             8  12626.8003
# 8             9  14393.3139
# 9            10  14828.5350
# 10           11  14199.4011
# 11           12  18726.1975

# %%
profit_by_month.plot.line()
plt.title('Monthly Profit Analysis')
fig.show()
# Out:
# C:\Users\Sopnil\AppData\Local\Temp\ipykernel_10440\2703134843.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# View Profit column groupby and Category data

# %%
profit_by_category = df.groupby('Category')['Profit'].sum().reset_index()
profit_by_category
# Out:
#           Category      Profit
# 0        Furniture  10006.6112
# 1  Office Supplies  74797.2461
# 2       Technology  90458.2486

# %% [markdown]
# Visualizations Category by Profit

# %%
fig=plt.figure(figsize=(12,7))
plt.title('Category by Profit')
sns.barplot(data=profit_by_category, x='Category',y ='Profit')
plt.show()

# %% [markdown]
# View sales column groupby and Sub-Category data

# %%
df_sub_category = df.groupby('Sub-Category')['Profit'].sum().reset_index()
df_sub_category
# Out:
#    Sub-Category      Profit
# 0   Accessories  25336.6455
# 1    Appliances  13166.6098
# 2           Art   3635.9257
# 3       Binders  17885.3759
# 4     Bookcases   -342.8883
# 5        Chairs  13406.7032
# 6       Copiers  42774.5828
# 7     Envelopes   3508.5073
# 8     Fasteners    598.4175
# 9   Furnishings   8034.4328
# 10       Labels   2937.2212
# 11     Machines     38.1024
# 12        Paper  21112.3779
# 13       Phones  22308.9179
# 14      Storage  13607.0875
# 15     Supplies  -1654.2767
# 16       Tables -11091.6365

# %%
plt.rcParams['figure.figsize']=(15,6)
colors = ['g' if p > 0 else 'r' for p in df.Profit]
plt.bar(df['Sub-Category'],df['Profit'],color=colors,);
plt.rcParams.update({'font.size':10});
plt.title('Profit by Sub-Category');
plt.xlabel('Sub_Category');
plt.ylabel('Profit');
plt.show()

# %% [markdown]
# If we look into the data region-wise, we can conclude that the south region needs more improvement compared to others.

# %%
df.corr()
sns.heatmap(df.corr(),cmap='Reds',annot=True);
plt.rcParams['figure.figsize']=(10,5)
# Out:
# C:\Users\Sopnil\AppData\Local\Temp\ipykernel_10440\112572111.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# C:\Users\Sopnil\AppData\Local\Temp\ipykernel_10440\112572111.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='Reds',annot=True);

# %%
df_new= df.filter(['Sales','Profit','Quantity','Order Month'])
df_new
# Out:
#          Sales   Profit  Quantity  Order Month
# 0       73.940  28.2668         1            1
# 1      173.940  38.2668         3            2
# 2      231.980  67.2742         2            2
# 3      114.460  28.6150         2            3
# 4       30.080  -5.2640         2            3
# ...        ...      ...       ...          ...
# 5896   213.136  12.1176         4           12
# 5897   295.904   4.5188         2           12
# 5898   388.024  -0.6048         3           12
# 5899   462.776  19.7910         3           12
# 5900  2975.510  -0.6048         3           12
#
# [5901 rows x 4 columns]

# %% [markdown]
# Show only meaning full columns heatmap

# %%
df_new.corr()
sns.heatmap(df_new.corr(),cmap='Reds',annot=True);
plt.rcParams['figure.figsize']=(10,5)

# %% [markdown]
# Conclusion <br>
# –> I have learned how to perform Exploratory Data Analysis.
#
# –> I performed it by using the sample superstore dataset.
#
# –>I have seen the loss areas in it and have seen some measures to overcome them.
#
# –> I have seen visualizations and drawn conclusions.

# %% [markdown]
# Author:<br>
# Md. Sairul Islam<br>
# github LInk: https://github.com/sahirul70 <br>
# Linkdin : https://www.linkedin.com/in/sairulislam/
